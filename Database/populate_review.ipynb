# %%
#INSERT INTO Review(idReview,description,rating,idGive,idReceive)VALUES(x1, x2,...);

# %%
#2008-11-11 13:23:44
from random import randint

def generate_postDate():
    string = ""
    
    # Data de criacao
    ano = randint(2022,2023)
    mes = randint(1,12)
   
    if mes == 1 or mes == 3 or mes == 5 or mes == 7 or mes == 8 or mes == 10 or mes == 12:
        dia = randint(1,31)
    elif mes == 2:
        #fuck you 29
        dia = randint(1,28)
    else:
        dia = randint(1,30)

    hora = randint(0,23)
    minuto = randint(0,59)
    segundo = randint(0,59)
    
    string+=str(ano)+"-"
    if mes < 10: 
        string+= "0" + str(mes)+"-"
    else:
        string+= str(mes)+"-"
    
    if dia < 10: 
        string+= "0" + str(dia)+" "
    else:
        string+= str(dia)+" "
    
    if hora < 10: 
        string+= "0" + str(hora)+":"
    else:
        string+= str(hora)+":"
    
    if minuto < 10: 
        string+= "0" + str(minuto)+":"
    else:
        string+= str(minuto)+":"
    
    if segundo < 10: 
        string+= "0" + str(segundo)
    else:
        string+= str(segundo)
    
    return string

# %%
from random import randint

def generate_rating():
    
    return randint(1,10)

# %%
from random import randint

def generate_aux(length):

    chars = "abcdefghijlmnopqrstuvxz "
    from os import urandom

    return "".join(chars[c % len(chars)] for c in urandom(length))

def generate_description():

    num = randint(1,1600)

    return generate_aux(num)

# %%
def get_sps():
    file_user = open("user.sql", "r")

    sp = []
    i = 0
    for row in file_user:
   
        if i == 0:
            i+=1
        else:
            x = row.split(",")
            if x[2] == "password" and x[16] == '3':
                y = x[10].split('(')
                sp.append(y[1])

    for i in sp:
        print(i)
        
    file_user.close()
    return sp

# %%
def get_consumers():
    file_user = open("user.sql", "r")

    consumer = []
    i = 0
    for row in file_user:
   
        if i == 0:
            i+=1
        else:
            x = row.split(",")
            if x[2] == "password" and x[16] == '2':
                y = x[10].split('(')
                consumer.append(y[1])

    for i in consumer:
        print(i)
        
    file_user.close()
    return consumer

# %%
from random import randint

def create_reviews(i,file,sps,consumers):
    j = 1
    tamanho_sps = len(sps)
    tamanho_consumers = len(consumers)
    
    while j < i+1:
        string = "INSERT INTO Review(idReview,description,rating,postDate,idGive,idReceive)VALUES(" + str(j) + ",'"
        string += generate_description() + "',"
        string += str(generate_rating()) + ",'"
        string += generate_postDate() + "',"
        
        num = randint(0,tamanho_consumers - 1)
        string += str(consumers[num]) + ","
        
        num2 = randint(0,tamanho_sps - 1)
        string += str(sps[num2]) + ");\n"
        
        file.write(string)
        j+=1
    
    file.close()

# %%
file = open("review.sql", "a")
file.write("USE PI;\n");

#1 admin | 2 consumer | 3 sp | 4 company 
sps = get_sps()
consumers = get_consumers()

create_reviews(100,file,sps,consumers)

file.close()
# Out:
# 3
# 4
# 5
# 9
# 19
# 21
# 23
# 36
# 40
# 42
# 46
# 49
# 58
# 61
# 62
# 65
# 67
# 76
# 81
# 83
# 85
# 93
# 94
# 105
# 107
# 110
# 114
# 115
# 117
# 118
# 119
# 121
# 122
# 125
# 126
# 134
# 138
# 144
# 146
# 147
# 148
# 149
# 152
# 155
# 158
# 162
# 168
# 169
# 170
# 179
# 180
# 185
# 188
# 189
# 192
# 194
# 197
# 199
# 204
# 209
# 210
# 211
# 214
# 215
# 218
# 222
# 224
# 228
# 229
# 234
# 235
# 236
# 238
# 241
# 243
# 245
# 248
# 249
# 255
# 257
# 258
# 259
# 260
# 262
# 264
# 265
# 266
# 272
# 273
# 274
# 277
# 279
# 282
# 288
# 292
# 296
# 298
# 309
# 324
# 325
# 327
# 328
# 329
# 330
# 334
# 341
# 344
# 345
# 347
# 348
# 350
# 351
# 352
# 358
# 359
# 360
# 363
# 365
# 366
# 372
# 373
# 374
# 381
# 382
# 388
# 389
# 393
# 397
# 399
# 400
# 405
# 406
# 409
# 410
# 412
# 415
# 416
# 419
# 421
# 426
# 431
# 433
# 436
# 441
# 450
# 453
# 454
# 455
# 456
# 461
# 465
# 468
# 475
# 484
# 488
# 490
# 491
# 492
# 497
# 500
# 1
# 2
# 6
# 7
# 8
# 10
# 11
# 12
# 14
# 15
# 16
# 17
# 18
# 20
# ...
